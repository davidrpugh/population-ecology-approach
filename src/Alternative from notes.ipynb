# %%
# %matplotlib inline

# %%
from IPython.html import widgets
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import sympy as sym

import equilibrium
import families
import simulators
import solvers

# %% [markdown]
# ## Alternative matching from notes
# A new matching function that might be useful because it’s so simple (and because if behaves more plausibly than Wright-Bergstrom in the limit) is exponential matching:
#
# $$ S(f_A,e) = \frac{(1+e) f_A}{(1+e)f_A + (1-e)f_a } $$
#
# Note that
#
# 1. $S(0,e) = 0$
# 2. $S(1,e) = 1$
# 3. $S(f_A,0) = f_A$
# 4. $S(f_A,1) = 1$
#
# So same as Wright-Bergstrom except for case 1: as A females become rare, the probability of finding one goes to zero.

# %%
# number of female children of particular genotype
female_offspring = sym.DeferredVector('f')

# assortativity parameter
e = sym.var('e')

altruistic_female_offspring = female_offspring[0] + female_offspring[2]
selfish_female_offspring = female_offspring[1] + female_offspring[3]
total_female_offspring = altruistic_female_offspring + selfish_female_offspring

# %%
# conditional phenotype matching probabilities (a la Wright/Bergstrom)
SGA = ((1 + e) * altruistic_female_offspring / 
       ((1 + e) * altruistic_female_offspring + (1 - e) * selfish_female_offspring))
Sga = ((1 - e) * selfish_female_offspring / 
       ((1 + e) * altruistic_female_offspring + (1 - e) * selfish_female_offspring))

# %%
params = {'c': 2.0, 'e': 0.5, 'PiaA': 7.0, 'PiAA': 5.0, 'Piaa': 3.0, 'PiAa': 2.0}

# %%
# create an instance of the Family class
family = families.OneMaleTwoFemales(params, SGA=SGA, Sga=Sga)

# create an instance of the Simulator class
simulator = simulators.Simulator(family)

# %% [markdown]
# ## Plotting shares of adult females by allele

# %%
# widget for varying the initial condition
eps = 1e-2
mGA0_widget = widgets.FloatSliderWidget(min=eps, max=1-eps, step=eps, value=0.5)
assortativity = widgets.FloatSliderWidget(min=eps, max=1-eps, step=0.05, value=0.05)
mGA0 = widgets.FloatSliderWidget(min=eps, max=1-eps, step=eps, value=0.5)
males = widgets.DropdownWidget(values=['genotypes', 'alpha_allele', 'gamma_allele'],
                               value='gamma_allele')
females = widgets.DropdownWidget(values=['genotypes', 'alpha_allele', 'gamma_allele'],
                                 value='alpha_allele')

# widgets for varying the payoffs
fecundity = widgets.IntSliderWidget(min=2.0, max=25, step=1, value=2.0)
exploitive_payoff = widgets.FloatSliderWidget(min=0.0, max=50.0, step=0.5, value=4.0)
cooperative_payoff = widgets.FloatSliderWidget(min=0.0, max=50.0, step=0.5, value=3.0)
selfish_payoff = widgets.FloatSliderWidget(min=0.0, max=50.0, step=0.5, value=2.0)
naive_payoff = widgets.FloatSliderWidget(min=0.0, max=50.0, step=0.5, value=1.0)

# %%
interactive_plot = widgets.interact(simulators.plot_isolated_subpopulations_simulation,
                                    simulator=widgets.fixed(simulator),
                                    mGA0=mGA0_widget,
                                    T=widgets.fixed(None),
                                    rtol=widgets.FloatTextWidget(value=1e-4),
                                    males=males,
                                    females=females,
                                    e=assortativity,
                                    c=fecundity,
                                    PiaA=exploitive_payoff,
                                    PiAA=cooperative_payoff,
                                    Piaa=selfish_payoff,
                                    PiAa=naive_payoff,
                                    )

# %% [markdown]
# # Selection pressure

# %% [markdown]
# ## Static plotting example

# %%
example_params = {'PiAA': 4.0, 'PiAa': 2.0, 'PiaA': 5.0, 'Piaa': 3.0, 'c': 2.0, 'e': 0.9}
simulators.plot_selection_pressure(simulator, mGA0=0.5, rtol=1e-4, **example_params)
plt.show()

# %% [markdown]
# ## Interactive plotting example

# %%
# widget for varying the initial condition and assortativity
eps = 1e-2
assortativity = widgets.FloatSliderWidget(min=eps, max=1-eps, step=eps, value=0.5)
mGA0 = widgets.FloatSliderWidget(min=eps, max=1-eps, step=eps, value=0.5)

# widgets for varying the payoffs
fecundity = widgets.IntSliderWidget(min=2.0, max=25, step=1, value=2.0)
exploitive_payoff = widgets.FloatSliderWidget(min=0.0, max=50.0, step=0.5, value=5.0)
cooperative_payoff = widgets.FloatSliderWidget(min=0.0, max=50.0, step=0.5, value=4.0)
selfish_payoff = widgets.FloatSliderWidget(min=0.0, max=50.0, step=0.5, value=3.0)
naive_payoff = widgets.FloatSliderWidget(min=0.0, max=50.0, step=0.5, value=2.0)

# %%
interactive_plot = widgets.interact(simulators.plot_selection_pressure,
                                    simulator=widgets.fixed(simulator),
                                    mGA0=mGA0,
                                    T=widgets.fixed(None),
                                    rtol=widgets.FloatTextWidget(value=1e-4),
                                    magnitude=True,
                                    e=assortativity,
                                    c=fecundity,
                                    PiaA=exploitive_payoff,
                                    PiAA=cooperative_payoff,
                                    Piaa=selfish_payoff,
                                    PiAa=naive_payoff,
                                    )

# %% [markdown]
# # Parameter sweeps

# %%
def parameter_sweep(eps, N, PiAA=4.0, PiAa=2.0, PiaA=5.0, Piaa=3.0):
    initial_conditions = np.linspace(eps, 1-eps, N)
    assortativities = np.linspace(eps, 1-eps, N)
    results = np.empty((N, N, 2))

    counter = 0
    for i, assortativity in enumerate(assortativities):
        for j, initial_condition in enumerate(initial_conditions):

            # run the simulation
            tmp_params = {'PiAA': PiAA, 'PiAa': PiAa, 'PiaA': PiaA, 'Piaa': Piaa,
                          'c': 2.0, 'e': assortativity}
            simulator.family.params = tmp_params
            simulator.initial_condition = initial_condition
            simulation = simulator.simulate(rtol=1e-6)
            distribution = simulators.Distribution(family, simulation)

            # store the results
            results[i, j, 0] = distribution.share_A_female_adults.iloc[-1]
            results[i, j, 1] = distribution.number_G_male_adults.iloc[-1]

            counter += 1
            if counter % 10 == 0:
                print("Done with {} out of {} simulations".format(counter, N**2))
                
    return results

# %% [markdown]
# ## Linear payoffs

# %%
linear_results = parameter_sweep(1e-2, 10, PiAA=4.0, PiAa=2.0, PiaA=5.0, Piaa=3.0)
# Out:
# Done with 1 out of 100 simulations
# Done with 2 out of 100 simulations
# Done with 3 out of 100 simulations
# Done with 4 out of 100 simulations
# Done with 5 out of 100 simulations
# Done with 6 out of 100 simulations
# Done with 7 out of 100 simulations
# Done with 8 out of 100 simulations
# Done with 9 out of 100 simulations
# Done with 10 out of 100 simulations
# Done with 11 out of 100 simulations
# Done with 12 out of 100 simulations
# Done with 13 out of 100 simulations
# Done with 14 out of 100 simulations
# Done with 15 out of 100 simulations
# Done with 16 out of 100 simulations
# Done with 17 out of 100 simulations
# Done with 18 out of 100 simulations
# Done with 19 out of 100 simulations
# Done with 20 out of 100 simulations
# Done with 21 out of 100 simulations
# Done with 22 out of 100 simulations
# Done with 23 out of 100 simulations
# Done with 24 out of 100 simulations
# Done with 25 out of 100 simulations
# Done with 26 out of 100 simulations
# Done with 27 out of 100 simulations
# Done with 28 out of 100 simulations
# Done with 29 out of 100 simulations
# Done with 30 out of 100 simulations
# Done with 31 out of 100 simulations
# Done with 32 out of 100 simulations
# Done with 33 out of 100 simulations
# Done with 34 out of 100 simulations
# Done with 35 out of 100 simulations
# Done with 36 out of 100 simulations
# Done with 37 out of 100 simulations
# Done with 38 out of 100 simulations
# Done with 39 out of 100 simulations
# Done with 40 out of 100 simulations
# Done with 41 out of 100 simulations
# Done with 42 out of 100 simulations
# Done with 43 out of 100 simulations
# Done with 44 out of 100 simulations
# Done with 45 out of 100 simulations
# Done with 46 out of 100 simulations
# Done with 47 out of 100 simulations
# Done with 48 out of 100 simulations
# Done with 49 out of 100 simulations
# Done with 50 out of 100 simulations
# Done with 51 out of 100 simulations
# Done with 52 out of 100 simulations
# Done with 53 out of 100 simulations
# Done with 54 out of 100 simulations
# Done with 55 out of 100 simulations
# Done with 56 out of 100 simulations
# Done with 57 out of 100 simulations
# Done with 58 out of 100 simulations
# Done with 59 out of 100 simulations
# Done with 60 out of 100 simulations
# Done with 61 out of 100 simulations
# Done with 62 out of 100 simulations
# Done with 63 out of 100 simulations
# Done with 64 out of 100 simulations
# Done with 65 out of 100 simulations
# Done with 66 out of 100 simulations
# Done with 67 out of 100 simulations
# Done with 68 out of 100 simulations
# Done with 69 out of 100 simulations
# Done with 70 out of 100 simulations
# Done with 71 out of 100 simulations
# Done with 72 out of 100 simulations
# Done with 73 out of 100 simulations
# Done with 74 out of 100 simulations
# Done with 75 out of 100 simulations
# Done with 76 out of 100 simulations
# Done with 77 out of 100 simulations
# Done with 78 out of 100 simulations
# Done with 79 out of 100 simulations
# Done with 80 out of 100 simulations
# Done with 81 out of 100 simulations
# Done with 82 out of 100 simulations
# Done with 83 out of 100 simulations
# Done with 84 out of 100 simulations
# Done with 85 out of 100 simulations
# Done with 86 out of 100 simulations
# Done with 87 out of 100 simulations
# Done with 88 out of 100 simulations
# Done with 89 out of 100 simulations
# Done with 90 out of 100 simulations
# Done with 91 out of 100 simulations
# Done with 92 out of 100 simulations
# Done with 93 out of 100 simulations
# Done with 94 out of 100 simulations
# Done with 95 out of 100 simulations
# Done with 96 out of 100 simulations
# Done with 97 out of 100 simulations
# Done with 98 out of 100 simulations
# Done with 99 out of 100 simulations
# Done with 100 out of 100 simulations

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 8), sharey=True)
mappable = axes[0].imshow(linear_results[:, :, 0], origin='lower', extent=[0, 1, 0, 1],
               vmin=0, vmax=1, interpolation='gaussian', cmap=mpl.cm.brg_r)
axes[1].imshow(linear_results[:, :, 1], origin='lower', extent=[0, 1, 0, 1],
               vmin=0, vmax=1, interpolation='gaussian', cmap=mpl.cm.brg_r)

axes[0].set_xlabel('Initial condition, $m^{GA}(0)$', fontsize=15, family='serif')
axes[1].set_xlabel('Initial condition, $m^{GA}(0)$', fontsize=15, family='serif')
axes[0].set_ylabel('Fraction of adults mating assortatively', fontsize=15, family='serif')
axes[0].grid('on')

axes[0].set_title(r'Females ($A$)', fontsize=20, family='serif')
axes[1].set_title(r'Males ($G$)', fontsize=20, family='serif')
axes[1].grid('on')

title = ('Equilibrium allele shares\n' +
         r'$\Pi^{{aA}}={PiaA},\ \Pi^{{AA}}={PiAA},\ ' +
         '\Pi^{{aa}}={Piaa},\ \Pi^{{Aa}}={PiAa}$')
fig.suptitle(title.format(**simulator.family.params), x=0.5, y=1.05,
             family='serif', fontsize=25)

# add a color bar
fig.subplots_adjust(right=0.8)
cax = fig.add_axes([0.85, 0.1, 0.075, 0.8])
fig.colorbar(mappable, cax=cax)

plt.show()

# %% [markdown]
# ## Returns to scarcity

# %%
return_to_scarcity_results = parameter_sweep(1e-2, 10, PiaA=7.0, PiAA=5.0, Piaa=3.0, PiAa=2.0)
# Out:
# Done with 10 out of 100 simulations
# Done with 20 out of 100 simulations
# Done with 30 out of 100 simulations
# Done with 40 out of 100 simulations
# Done with 50 out of 100 simulations
# Done with 60 out of 100 simulations
# Done with 70 out of 100 simulations
# Done with 80 out of 100 simulations
# Done with 90 out of 100 simulations
# Done with 100 out of 100 simulations

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 8), sharey=True)
mappable = axes[0].imshow(return_to_scarcity_results[:, :, 0], origin='lower',
                          extent=[0, 1, 0, 1], vmin=0, vmax=1,
                          interpolation='gaussian', cmap=mpl.cm.brg_r)
axes[1].imshow(return_to_scarcity_results[:, :, 1], origin='lower', extent=[0, 1, 0, 1],
               vmin=0, vmax=1, interpolation='gaussian', cmap=mpl.cm.brg_r)

axes[0].set_xlabel('Initial condition, $M^{GA}(0)$', fontsize=15, family='serif')
axes[1].set_xlabel('Initial condition, $M^{GA}(0)$', fontsize=15, family='serif')
axes[0].set_ylabel('Assortativity parameter, $e$', fontsize=15, family='serif')
axes[0].grid('on')

axes[0].set_title(r'Females ($A$)', fontsize=20, family='serif')
axes[1].set_title(r'Males ($G$)', fontsize=20, family='serif')
axes[1].grid('on')

title = ('Equilibrium allele shares\n' +
         r'$\Pi^{{aA}}={PiaA},\ \Pi^{{AA}}={PiAA},\ ' +
         '\Pi^{{aa}}={Piaa},\ \Pi^{{Aa}}={PiAa}$')

fig.suptitle(title.format(**simulator.family.params), x=0.5, y=1.05,
             family='serif', fontsize=25)

# add a color bar
fig.subplots_adjust(right=0.8)
cax = fig.add_axes([0.85, 0.1, 0.075, 0.8])
fig.colorbar(mappable, cax=cax)

plt.show()

# %% [markdown]
# ## Hierarchy

# %%
hierarchy_results = parameter_sweep(1e-2, 10, PiaA=9.0, PiAA=5.0, Piaa=3.0, PiAa=2.0)
# Out:
# Done with 10 out of 100 simulations
# Done with 20 out of 100 simulations
# Done with 30 out of 100 simulations
# Done with 40 out of 100 simulations
# Done with 50 out of 100 simulations
# Done with 60 out of 100 simulations
# Done with 70 out of 100 simulations
# Done with 80 out of 100 simulations
# Done with 90 out of 100 simulations
# Done with 100 out of 100 simulations

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 8), sharey=True)
mappable = axes[0].imshow(hierarchy_results[:, :, 0], origin='lower',
                          extent=[0, 1, 0, 1], vmin=0, vmax=1,
                          interpolation='gaussian', cmap=mpl.cm.brg_r)
axes[1].imshow(hierarchy_results[:, :, 1], origin='lower', extent=[0, 1, 0, 1],
               vmin=0, vmax=1, interpolation='gaussian', cmap=mpl.cm.brg_r)

axes[0].set_xlabel('Initial condition, $M^{GA}(0)$', fontsize=15, family='serif')
axes[1].set_xlabel('Initial condition, $M^{GA}(0)$', fontsize=15, family='serif')
axes[0].set_ylabel('Assortativity parameter, $e$', fontsize=15, family='serif')
axes[0].grid('on')

axes[0].set_title(r'Females ($A$)', fontsize=20, family='serif')
axes[1].set_title(r'Males ($G$)', fontsize=20, family='serif')
axes[1].grid('on')

title = ('Equilibrium allele shares\n' +
         r'$\Pi^{{aA}}={PiaA},\ \Pi^{{AA}}={PiAA},\ ' +
         '\Pi^{{aa}}={Piaa},\ \Pi^{{Aa}}={PiAa}$')

params = {'PiAA': 4.0, 'PiAa': 2.0, 'PiaA': 7.0, 'Piaa': 3.0}
fig.suptitle(title.format(**simulator.family.params), x=0.5, y=1.05,
             family='serif', fontsize=25)

# add a color bar
fig.subplots_adjust(right=0.8)
cax = fig.add_axes([0.85, 0.1, 0.075, 0.8])
fig.colorbar(mappable, cax=cax)

plt.show()
